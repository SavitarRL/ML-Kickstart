# %% [markdown]
# ### QNN with Tensorflow Quantum
#
# as from https://www.tensorflow.org/quantum/tutorials/mnist
#
# paper ref: https://arxiv.org/pdf/1802.06002.pdf

# %%
import importlib, pkg_resources
importlib.reload(pkg_resources)
# Out:
# <module 'pkg_resources' from 'c:\\Users\\ryanl\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\pkg_resources\\__init__.py'>

# %%
import tensorflow as tf
# import tensorflow_quantum as tfq

import cirq
import sympy
import numpy as np
import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %%
from mnist_model import *

mnistmodel = MnistModel(batch_size=100)

mnist_training = MnistTrainingModel(mnistmodel)

mnist_testing = MnistTestingModel(mnistmodel)
